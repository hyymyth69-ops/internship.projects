# %% [markdown]
# <a href="https://colab.research.google.com/github/hyymyth69-ops/internship.projects/blob/main/fake_news_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# Fake news data
data = {
    "text": [
        "Aliens attacked Mumbai yesterday",
        "Drinking petrol cures fever",
        "India won the cricket match",
        "Government launched new policy"
    ],
    "label": [
        "FAKE",
        "FAKE",
        "REAL",
        "REAL"
    ]
}

# Create dataframe
df = pd.DataFrame(data)

# Convert text into numbers
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df["text"])

# Train model
model = LogisticRegression()
model.fit(X, df["label"])

# User input
news = input("Enter News: ")

# Predict
news_vector = vectorizer.transform([news])
prediction = model.predict(news_vector)

print("Prediction:", prediction[0])
# Out:
# Enter News: india won the match
# Prediction: REAL
