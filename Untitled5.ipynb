# %% [markdown]
# <a href="https://colab.research.google.com/github/hyymyth69-ops/internship.projects/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

data = {
    'area': [1000, 1200, 1500, 1800, 2000],
    'rooms': [2, 3, 3, 4, 4],
    'price': [20, 25, 30, 40, 45]
}

df = pd.DataFrame(data)

x = df[['area', 'rooms']]
y = df['price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

model = LinearRegression()

model.fit(x_train, y_train)

area = int(input("Enter area: "))
rooms = int(input("Enter rooms: "))

prediction = model.predict([[area, rooms]])

print("Predicted Price:", prediction)
# Out:
# Enter area: 2000
# Enter rooms: 5
# Predicted Price: [46.25]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
